# %%
GOOGLE_API_KEY = "AIzaSyCD0qRSUJyBxD2XrlhRRepfgxeRh0-qS94"

# %%
new_data_path = fr"C:\Users\Noodl\Projects\Big_O\Hackathon\GenAI2K25\english_news_cleaned_for_indic_bert.csv"

# %%
import pandas as pd

# %%
scraped_articles = pd.read_csv(fr"C:\Users\Noodl\Projects\Mini_Project\Prisma_Scraper\scraped_news.csv")

# %%
definition_political_bias = """POLITICAL_BIAS
Definition: A sustained pattern in news coverage where editorial decisions consistently favor or disadvantage particular political actors, parties, policies, or ideologies, shaping the narrative to align with specific political interests. Evidenced by the deliberate inclusion of supportive evidence, expert commentary, or success stories for one side, while minimizing, omitting, or discrediting opposing viewpoints through selective sourcing and context removal. Reflected in the disproportionate allocation of visibility—such as longer articles, prominent headlines, and rich multimedia elements—to narratives that bolster certain political agendas, creating an imbalanced portrayal of issues. Detected through systematic analysis of framing devices, such as loaded language that casts one policy as "transformative reform" while labeling its alternative as "misguided proposal," thereby guiding reader interpretation along partisan lines.

Classify when:

    Articles consistently favor one political party/ideology across multiple issues

    Unequal sourcing where one side gets expert validation while opposition receives only criticism

    Systematic use of positive language for preferred politicians and negative framing for opponents

    Selective reporting that highlights achievements of one party while downplaying similar achievements of others

Not classify when:

    Balanced reporting that includes multiple political perspectives with equal treatment

    Critical analysis that applies similar scrutiny standards across political actors

    Factual reporting of political events without editorial commentary or loaded language

    Opinion pieces clearly labeled as editorials or columns with disclosed political stance"""

example_political_bias ="""Example (India): A major national newspaper extensively covers the government's flagship economic scheme with detailed success metrics and glowing expert endorsements, while publishing only brief, context-less critiques of the policy's shortcomings in a sidebar.

    Example (World): An international news agency describes Country A's diplomatic overture as "a landmark peace initiative," yet refers to Country B's identical proposal as "a strategic maneuver to expand influence," despite comparable content and context.
"""

definition_gender_bias = """GENDER_BIAS
Definition: A pervasive tendency in news articles to reinforce traditional gender stereotypes and unequal power dynamics by the way individuals are represented, described, and contextualized. Manifests as chronic underrepresentation of women, nonbinary, and transgender individuals in bylines, quotes, and expert analyses, implicitly signaling that certain genders are less authoritative or credible. Revealed through language choices that mark one gender with relational identifiers (e.g., "the CEO and her husband") or diminish professional roles by emphasizing appearance, family status, or emotional attributes for women, while exclusively highlighting credentials and achievements for men. Identified by the inconsistent use of neutral job titles and honorifics—referring to a "nurse" by gendered pronouns but omitting gender markers for equivalent male roles—thereby perpetuating assumptions about default gender roles in various professions.

Classify when:

    Differential treatment in how men and women are described (credentials vs. appearance/relationships)

    Systematic underrepresentation of women or minorities in expert commentary roles

    Use of gendered language that reinforces stereotypes about professional capabilities

    Emphasis on family roles for women while focusing on professional achievements for men

Not classify when:

    Equal representation and treatment across genders in sourcing and description

    Relevant mention of personal details when equally applied to all subjects regardless of gender

    Gender-specific coverage when the story's focus legitimately centers on gender-related issues

    Factual reporting that doesn't employ differential descriptive standards"""
example_gender_bias = """

    Example (India): In reporting a medical breakthrough, a health magazine refers to the male lead researcher by his academic title and institution, but describes the female co-researcher primarily in terms of her marital status and attire during the press conference.

    Example (World): A global business journal publishes profiles of technology founders, detailing male founders' innovative strategies and risk-taking, while focusing on female founders' parenting responsibilities and work–life balance challenges.
"""

definition_cultural_bias = """CULTURAL_BIAS (including Religious Bias)
Definition: The systematic imposition of a dominant cultural or religious group's worldview onto other communities within news reporting, leading to distorted, marginalizing, or superior portrayals of minority cultures and faiths. Appears through ethnocentric descriptions that label non-dominant traditions as "primitive," "superstitious," or "exotic spectacle," without providing the historical, social, or theological context necessary for nuanced understanding. Evident in the omission of voices from the community being described—such as tribal elders or minority religious scholars—resulting in one-sided narratives that privilege the dominant group's interpretations and values. Encompasses religious bias when events involving faith communities are framed in monolithic terms (e.g., portraying all members of a religion as unified in extremist views), ignoring intra-faith diversity and reinforcing harmful stereotypes.

Classify when:

    Ethnocentric language that positions one culture as superior or more civilized than others

    Systematic omission of voices from the communities being covered

    Use of stereotypical or exotic descriptors without contextual explanation

    Monolithic portrayal of religious groups without acknowledging internal diversity

    Coverage that reduces complex cultural practices to simplistic caricatures

Not classify when:

    Respectful reporting that includes community voices and contextual background

    Neutral description of cultural differences without value judgments

    Coverage that acknowledges diversity within cultural or religious groups

    Educational content that explains cultural practices with appropriate historical context

    Critical analysis that applies consistent standards across different cultures
"""
example_cultural_bias = """
    Example (India): Coverage of a tribal harvest ritual labels it as "archaic superstition" and features commentary exclusively from urban academics, omitting perspectives of tribal leaders who explain its ecological and communal significance.

    Example (World): A Western travel blog describes a Southeast Asian religious festival as "an exotic carnival," trivializing its theological importance and omitting explanations from local religious scholars.
"""
definition_ideo_bias = """
IDEOLOGICAL_BIAS (Stance Bias)
Definition: A consistent pattern in news articles where information is curated, emphasized, or structured to advance a specific ideological stance or set of beliefs, regardless of overt political affiliation. Characterized by thematic prioritization of issues resonating with the ideology—such as framing economic debates exclusively around market freedom or social justice—while systematically excluding data, expert opinions, or narratives that challenge the chosen worldview. Revealed through narrative arc construction that foregrounds sources committed to the preferred ideology—quoting think-tank analysts, opinion leaders, or advocacy groups aligned with that stance—while marginalizing or omitting voices from alternative philosophical traditions. Detected by examining consistency of value-laden language across multiple articles, such as repeatedly describing government intervention as "bureaucratic overreach" in a libertarian frame or characterizing corporate practices as "profit-driven exploitation" in a social-democratic frame.

Classify when:

    Systematic exclusion of perspectives that challenge the preferred ideological framework

    Consistent use of value-laden language that reflects specific philosophical commitments

    Selective presentation of evidence that supports only one ideological interpretation

    Sourcing patterns that heavily favor experts from aligned think tanks or advocacy groups

    Framing of neutral events through ideologically-charged terminology

Not classify when:

    Balanced presentation of multiple ideological perspectives on complex issues

    Use of neutral, descriptive language without embedded value judgments

    Inclusion of diverse expert sources representing different philosophical approaches

    Clear labeling when presenting opinion or editorial content with disclosed ideological stance

    Factual reporting that allows readers to form their own interpretive frameworks
"""
example_ideo_bias = """
    Example (India): An economic daily frames a new labor rights law solely through commentary from free-market economists, labeling union leaders' concerns as "alarmist," and ignores studies showing potential benefits for worker welfare.

    Example (World): An environmental magazine presents climate policy exclusively through statements by conservation NGOs and activist scientists, while omitting perspectives from energy-sector stakeholders on transition challenges and economic trade-offs.
"""

# %%
no_bias = """OVERALL NEUTRAL REPORTING CHARACTERISTICS:

    Balanced Sourcing: Equal access and representation for relevant stakeholders

    Consistent Language Standards: Uniform descriptive and evaluative terminology across all subjects

    Factual Focus: Emphasis on verifiable information over interpretive commentary

    Contextual Completeness: Inclusion of relevant background information and diverse perspectives

    Transparent Methodology: Clear identification of sources and reporting processes
"""
no_political_bias = """NON-POLITICAL_BIAS (Neutral Political Reporting)
Definition: News coverage that maintains editorial neutrality by providing equal treatment to all political actors, parties, and ideologies. Characterized by balanced sourcing that includes diverse political perspectives, consistent application of descriptive language across party lines, proportional coverage allocation based on newsworthiness rather than political preference, and factual presentation that allows readers to form independent judgments without editorial influence.

Example (India): "The Lok Sabha passed the education reform bill with 285 votes in favor and 112 against. BJP spokesperson stated the bill would 'modernize curriculum standards,' while Congress representative argued it 'lacks adequate funding provisions.' Independent education policy experts noted both potential benefits and implementation challenges."

Example (World): "President A announced new trade tariffs on steel imports. The policy affects 15% of domestic steel consumption. Industry representatives expressed concerns about supply chain impacts, while administration officials cited national security considerations. Economic analysts provided mixed assessments of potential market effects."""
no_gender_bias = """NON-GENDER_BIAS (Gender-Neutral Reporting)
Definition: News content that treats individuals equally regardless of gender identity, avoiding stereotypical assumptions or differential treatment. Characterized by consistent professional descriptors across all genders, equal representation in expert sourcing and bylines, uniform focus on credentials and achievements rather than appearance or relational status, and language choices that do not reinforce traditional gender role expectations.

Example (India): "Dr. Priya Sharma, cardiothoracic surgeon at AIIMS, and Dr. Rajesh Gupta, pulmonologist at PGIMER, jointly published research on minimally invasive cardiac procedures. Both physicians have over 15 years of surgical experience and have contributed to advances in their respective specializations."

Example (World): "The technology conference featured keynote presentations from CEO Maria Rodriguez of TechCorp, discussing artificial intelligence applications, and CTO James Chen of DataSystems, presenting cybersecurity innovations. Both speakers highlighted their companies' research and development initiatives."""
no_cultural_bias = """NON-CULTURAL_BIAS (Culturally Neutral Reporting)
Definition: News coverage that presents different cultural and religious communities without imposing dominant group values or assumptions. Characterized by inclusion of community voices in stories about their own practices, respectful terminology that avoids exotic or hierarchical descriptors, provision of appropriate historical and social context, and recognition of internal diversity within cultural and religious groups.

Example (India): "The Hornbill Festival celebrates Naga cultural heritage through traditional music, dance, and crafts. Festival organizer John Doule explained that the event preserves ancestral traditions while promoting cultural exchange. Various Naga tribes participate, each contributing distinct ceremonial elements that reflect their unique histories and customs."

Example (World): "Ramadan observance varies across Muslim communities worldwide. Local mosque leader Imam Hassan described fasting practices and community iftar gatherings. Islamic scholar Dr. Fatima Ahmed noted that interpretation and implementation of religious obligations differ among various Islamic schools of thought and cultural contexts."""
no_ideology_bias = """NON-IDEOLOGICAL_BIAS (Ideologically Neutral Reporting)
Definition: News presentation that avoids systematic alignment with specific belief systems or worldviews. Characterized by inclusion of multiple philosophical perspectives on complex issues, neutral descriptive language without embedded value judgments, diverse expert sourcing across ideological spectrums, and factual reporting that presents information without predetermined interpretive frameworks.

Example (India): "The minimum wage increase proposal has generated diverse responses. Labor union representative advocated for higher wages to address inflation costs. Industry association spokesperson expressed concerns about employment impacts. Economic researchers presented data on wage policy effects in comparable economies, showing varied outcomes across different sectors."

Example (World): "Climate policy negotiations include carbon pricing mechanisms. Environmental scientists support emissions reduction targets. Energy industry representatives emphasize transition timeline feasibility. Developing nation delegates stress economic development needs. Each stakeholder group presented evidence-based arguments for their positions."""

# %%
summarise_prompt = """You are a professional news summarizer tasked with creating comprehensive yet concise summaries of news articles. Your goal is to distill the essential information while preserving the complete narrative and original perspective.
Core Requirements:

Preserve Original Stance: Maintain the exact editorial perspective, tone, and viewpoint presented in the original article. Do not neutralize bias or alter the author's intended framing—reproduce it faithfully.

Complete Information Retention: Include all critical details that contribute to understanding the story:

    All proper names (people, places, organizations, institutions)

    Specific dates, numbers, statistics, and quantitative data

    Direct quotes that capture key positions or revelations

    Cause-and-effect relationships and chronological sequences

    Background context necessary for comprehension

Eliminate Non-Essential Elements: Remove without losing substance:

    Redundant statements and repetitive phrasing

    Excessive descriptive language that doesn't add factual content

    Tangential anecdotes unrelated to the main narrative

    Filler transitions and verbose connector phrases

    Secondary sources that merely echo primary information

Maintain Expressiveness: Preserve the article's communicative style:

    Retain impactful language choices that convey the author's intended emphasis

    Keep emotional tone and urgency level consistent with the original

    Preserve rhetorical devices that serve the article's persuasive goals

    Maintain the logical flow and argumentative structure

Structure Guidelines:

    Lead Summary: Open with the most newsworthy information in 2-3 sentences

    Key Details: Present essential facts, figures, names, and quotes in order of importance

    Context and Background: Include necessary historical or situational context

    Stakeholder Perspectives: Capture all relevant viewpoints with proper attribution

    Implications: Conclude with consequences or future developments mentioned in the article

Quality Checks:

    Can a reader understand the complete story from your summary alone?

    Are all mentioned names, dates, and statistics preserved?

    Does the summary reflect the same editorial stance as the original?

    Would the original author recognize their perspective in your condensed version?

    Have you eliminated wordiness without losing substantive content?

Create a summary that serves as a faithful, complete, and efficiently expressed version of the original article."""

# %%
scraped_articles.drop(columns=['Unnamed: 0', 'article_length'], inplace=True)

# %%
scraped_articles.drop(columns=['url','label'], inplace=True)

# %%
scraped_articles
# Out:
#                                                 article
# 0     india has outrightly rejected trudeaus allegat...
# 1     word on the street is that the bjp made a monu...
# 2     doctors at a hospital in punjabs moga were in ...
# 3     us state department spokesperson mathew miller...
# 4     india won sco backing against terrorism as the...
# ...                                                 ...
# 9959  the next wave of socialist politicians will br...
# 9960  socialism can work socialism communism as is b...
# 9961  two ways gradually and then suddenly thats the...
# 9962  elizabeth warren has secretly been embracing s...
# 9963  exgov andrew cuomo is resuscitating his moribu...
#
# [9964 rows x 1 columns]

# %%
dataset_1 = pd.read_csv(fr"C:\Users\Noodl\Downloads\allsides_balanced_news_headlines-texts.csv")

# %%
dataset_1
# Out:
#        Unnamed: 0                                              title  \
# 0               0           Gun Violence Over Fourth of July Weekend
# 1               1           Gun Violence Over Fourth of July Weekend
# 2               2           Gun Violence Over Fourth of July Weekend
# 3               3  Yellen Warns Congress of 'Economic Recession' ...
# 4               4  Yellen Warns Congress of 'Economic Recession' ...
# ...           ...                                                ...
# 21749       21749  Biden Seeks $30 Billion For Disaster Aid And R...
# 21750       21750  Biden Seeks $30 Billion For Disaster Aid And R...
# 21751       21751                      US House Condemns QAnon Group
# 21752       21752                      US House Condemns QAnon Group
# 21753       21753                      US House Condemns QAnon Group
#
#                                                     tags  \
# 0      ['Protests', 'Fourth Of July', 'Gun Control An...
# ...

# %%
dataset_2 = pd.read_csv(fr"C:\Users\Noodl\Downloads\train_annotated_7000.csv")

# %%
dataset_2
# Out:
#                                              input_text  \
# 0     rule it as a hate crime he was a liberal with ...
# 1     boo ! no theatre for us today . I 'm so fuckin...
# 2     This case is more than about rape , which in i...
# 3     Our patriarchs have preached this but these id...
# 4     `` `` Let me be clear , '' he ( Nunes ) said ....
# ...                                                 ...
# 7487  Charles - the Relublicans did not steer soluti...
# 7488  Actually , we do n't need to boycott chinese g...
# 7489  @ lifebystereo You should have told the kid 's...
# 7490  The only Kroenke vision : Be good enough not t...
# 7491  There is a new model out that suggests that Hu...
#
#                                           debiased_text
# 0     A: The original statement contains bias in the...
# 1     A: The original statement contains biased lang...
# 2     A: The original statement contains biased lang...
# 3     A: The biased statement in the original text i...
# ...
