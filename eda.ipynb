# %%
import pandas as pd

# %%
data = pd.read_csv(fr"/home/IAteNoodles/Projects/Mini_Project/Prisma_Scraper/articles.csv")

# %%
data
# Out:
#                                                   url  \
# 0   https://www.theverge.com/news/761582/apple-iph...
# 1   https://gizmodo.com/tim-cook-to-appear-with-tr...
# 2   https://www.bbc.com/sport/cricket/videos/cger9...
# 3   https://www.bbc.co.uk/iplayer/episode/m002gk44...
# 4      https://www.bbc.com/news/articles/cj3lxzpkn87o
# ..                                                ...
# 72  https://www.businessinsider.com/h-1b-visa-big-...
# 73  https://gizmodo.com/this-newly-launched-satell...
# 74  https://gizmodo.com/apples-tim-cook-talks-trum...
# 75  https://www.xataka.com/empresas-y-economia/ind...
# 76  https://slashdot.org/story/25/08/14/0811259/ch...
#
#                                                  text
# 0   Apple is manufacturing more of its iPhone 17 p...
# 1   Apple CEO Tim Cook will join President Donald ...
# 2   India enjoy late recovery as Woakes injury ove...
# 3   Main content\nFifth Test, Day 1\nDay 1 highlig...
# ...
